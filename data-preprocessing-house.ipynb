# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('independent-house - independent-house.csv')
df.sample(5)
# Out:
#                                       property_name  \
# 1008  5 Bedroom House for sale in Sector 33 Gurgaon
# 842     3 Bedroom House for sale in Nirvana Country
# 1011    4 Bedroom House for sale in Nirvana Country
# 352        2 Bedroom House for sale in Laxman Vihar
# 979   5 Bedroom House for sale in Sector 14 Gurgaon
#
#                                                    link  \
# 1008  https://www.99acres.com/5-bhk-bedroom-independ...
# 842   https://www.99acres.com/3-bhk-bedroom-independ...
# 1011  https://www.99acres.com/4-bhk-bedroom-independ...
# 352   https://www.99acres.com/2-bhk-bedroom-independ...
# 979   https://www.99acres.com/5-bhk-bedroom-independ...
#
#                        society       price             rate  \
# 1008  Unitech Uniworld Resorts    11 Crore  ₹ 26,667/sq.ft.
# 842       Unitech Aspen Greens    12 Crore  ₹ 37,037/sq.ft.
# 1011            Unitech Espace  7.42 Crore  ₹ 34,351/sq.ft.
# 352                        NaN  1.25 Crore  ₹ 78,125/sq.ft.
# ...

# %%
df.shape
# Out:
# (1037, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1037 non-null   object
#  1   link             1037 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             999 non-null    object
#  5   area             1037 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1024, 21)

# %%
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            579
# price               69
# rate                38
# area                 0
# areaWithType        50
# bedRoom             50
# bathroom            50
# balcony             50
# additionalRoom     446
# address              6
# noOfFloor           69
# facing             362
# agePossession       50
# nearbyLocations    124
# description          1
# furnishDetails     292
# features           362
# rating             130
# property_id          1
# dtype: int64

# %%
df.drop(columns = ['link' , 'property_id'] , inplace = True)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df.rename(columns = {'rate' : 'price_per_sqft'} , inplace = True)
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['society'].isna().sum()
# Out:
# 579

# %%
df['society'] = df['society'].fillna('independent')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['price'].value_counts()
# Out:
# price
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 5 Crore             13
# 4.5 Crore           13
# 70 Lac              13
# 8 Crore             13
# 50 Lac              13
# 75 Lac              13
# 8.5 Crore           12
# 7 Crore             12
# 85 Lac              12
# 1.5 Crore           11
# 4 Crore             11
# 10 Crore            10
# Price on Request    10
# 45 Lac              10
# 2.25 Crore          10
# 2.5 Crore           10
# 60 Lac              10
# 90 Lac              10
# 9 Crore             10
# 9.5 Crore            9
# 12 Crore             9
# 80 Lac               9
# 1.7 Crore            9
# 2 Crore              9
# 1.1 Crore            9
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 1.6 Crore            8
# 4.6 Crore            8
# 1.3 Crore            7
# 95 Lac               7
# 12.5 Crore           7
# 3.75 Crore           7
# 1.2 Crore            7
# ...

# %%
df = df[df['price'] != 'Price on Request']

# %%
def treat_prices(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100 , 2)
        else:
            return round(float(x[0]) , 2)

# %%
df['price'] = df['price'].str.split(' ').apply(treat_prices)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     11
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 26,667/sq.ft.      6
# ₹ 37,037/sq.ft.      6
# ₹ 26,235/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 9,444/sq.ft.       5
# ₹ 23,333/sq.ft.      5
# ₹ 23,148/sq.ft.      5
# ₹ 13,333/sq.ft.      5
# ₹ 11,100/sq.ft.      5
# ₹ 8,000/sq.ft.       5
# ₹ 8,889/sq.ft.       5
# ₹ 5,000/sq.ft.       5
# ₹ 9,722/sq.ft.       4
# ₹ 34,722/sq.ft.      4
# ₹ 32,407/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 18,889/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 35,000/sq.ft.      4
# ₹ 6,944/sq.ft.       3
# ₹ 13,889/sq.ft.      3
# ₹ 20,000/sq.ft.      3
# ₹ 16,058/sq.ft.      3
# ₹ 8,235/sq.ft.       3
# ₹ 36,111/sq.ft.      3
# ₹ 12,222/sq.ft.      3
# ₹ 50,000/sq.ft.      3
# ₹ 8,333/sq.ft.       3
# ₹ 14,815/sq.ft.      3
# ₹ 12,000/sq.ft.      3
# ₹ 25,000/sq.ft.      3
# ₹ 15,555/sq.ft.      3
# ₹ 10,556/sq.ft.      3
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹' , '')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      31
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                       property_name  \
# 62   5 Bedroom House for sale in Sector 109 Gurgaon
# 63   4 Bedroom House for sale in Sector 109 Gurgaon
# 66    5 Bedroom House for sale in Sector 66 Gurgaon
# 67    4 Bedroom House for sale in Sector 66 Gurgaon
# 68   5 Bedroom House for sale in Sector 109 Gurgaon
# 69   4 Bedroom House for sale in Sector 109 Gurgaon
# 70   3 Bedroom House for sale in Sector 109 Gurgaon
# 71   4 Bedroom House for sale in Sector 112 Gurgaon
# 72    4 Bedroom House for sale in Sector 66 Gurgaon
# 73    5 Bedroom House for sale in Sector 66 Gurgaon
# 74    4 Bedroom House for sale in Sector 66 Gurgaon
# 75    3 Bedroom House for sale in Sector 73 Gurgaon
# 76   5 Bedroom House for sale in Sector 109 Gurgaon
# 77   4 Bedroom House for sale in Sector 109 Gurgaon
# 78   3 Bedroom House for sale in Sector 109 Gurgaon
# 81    5 Bedroom House for sale in Sector 66 Gurgaon
# 82    4 Bedroom House for sale in Sector 66 Gurgaon
# ...

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.shape
# Out:
# (964, 19)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      28
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No' , '0')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Store Room,Study Room,Servant Room     8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
df['additionalRoom'].fillna('not available' , inplace = True)
# Out:
# C:\Users\virat\AppData\Local\Temp\ipykernel_20268\196059762.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available' , inplace = True)

# %%
df['additionalRoom'].isna().sum()
# Out:
# 0

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df['noOfFloor'].value_counts()
# Out:
# noOfFloor
# 3 Floors     304
# 2 Floors     288
# 1 Floors     181
# 4 Floors     136
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: count, dtype: int64

# %%
df['noOfFloor'].isnull().sum()
# Out:
# 19

# %%
df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)

# %%
df.reset_index(drop = True , inplace = True)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df.rename(columns = {'noOfFloor' : 'floorNum'} , inplace = True)
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#   price_per_sqft                   area                 areaWithType  bedRoom  \
# 0         20,115  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)        5
# 1        105,751   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)        5
# 2         38,251   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)       10
# 3         43,066  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)       21
# 4         53,763   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)       12
#
# ...

# %%
df['facing'].fillna('NA' , inplace = True)
# Out:
# C:\Users\virat\AppData\Local\Temp\ipykernel_20268\2124479262.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA' , inplace = True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            303
# East          178
# North-East    158
# North         109
# West           75
# North-West     44
# South-East     39
# South          34
# South-West     24
# Name: count, dtype: int64

# %%
df['area'] = round((df['price'] * 10000000) / df['price_per_sqft'])

# %%
df['price_per_sqft'] = df['price_per_sqft'].astype(str).str.replace('₹', '', regex=False) \
                                          .str.replace(',', '', regex=False) \
                                          .str.replace(' per sqft', '', regex=False) \
                                          .str.strip()

# %%
df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'], errors='coerce')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft    area                 areaWithType  bedRoom  bathroom  \
# 0         20115.0  2610.0  Plot area 290(242.48 sq.m.)        5         4
# 1        105751.0   539.0   Plot area 539(50.07 sq.m.)        5         4
# 2         38251.0   549.0       Plot area 61(51 sq.m.)       10        10
# 3         43066.0  1161.0  Plot area 129(107.86 sq.m.)       21        21
# 4         53763.0   558.0    Plot area 62(51.84 sq.m.)       12        12
#
#   balcony                      additionalRoom  \
# ...

# %%
df.insert(loc = 1 , column = 'property_type' , value )
