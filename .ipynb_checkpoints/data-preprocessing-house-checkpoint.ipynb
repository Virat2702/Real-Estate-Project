# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('independent-house - independent-house.csv')
df.sample(5)
# Out:
#                                         property_name  \
# 319        34 Bedroom House for sale in Manohar Nagar
# 592         2 Bedroom House for sale in Rajendra Park
# 482     7 Bedroom House for sale in Sector 11 Gurgaon
# 5    20 Bedroom House for sale in Sushant Lok Phase 1
# 810     4 Bedroom House for sale in Sector 26 Gurgaon
#
#                                                   link        society  \
# 319  https://www.99acres.com/34-bhk-bedroom-indepen...  MANOHAR NAGAR
# 592  https://www.99acres.com/2-bhk-bedroom-independ...            NaN
# 482  https://www.99acres.com/7-bhk-bedroom-independ...            NaN
# 5    https://www.99acres.com/20-bhk-bedroom-indepen...            NaN
# 810  https://www.99acres.com/4-bhk-bedroom-independ...            NaN
#
#          price             rate                       area  \
# 319  5.6 Crore  ₹ 12,444/sq.ft.      (418 sq.m.) Plot Area
# 592  9.9 Crore  ₹ 49,500/sq.ft.  (186 sq.m.) Built-up Area
# 482  1.2 Crore   ₹ 4,444/sq.ft.  (251 sq.m.) Built-up Area
# 5    4.5 Crore  ₹ 39,062/sq.ft.      (107 sq.m.) Plot Area
# 810  5.8 Crore  ₹ 12,837/sq.ft.      (420 sq.m.) Plot Area
#
#                                           areaWithType      bedRoom  \
# 319  Plot area 500(418.06 sq.m.)Built Up area: 500 ...  34 Bedrooms
# 592  Built Up area: 2000 (185.81 sq.m.)Carpet area:...   2 Bedrooms
# 482                  Built Up area: 300 (250.84 sq.m.)   7 Bedrooms
# 5                          Plot area 128(107.02 sq.m.)  20 Bedrooms
# 810                        Plot area 502(419.74 sq.m.)   4 Bedrooms
#
#          bathroom       balcony additionalRoom  \
# 319  34 Bathrooms  3+ Balconies            NaN
# 592   2 Bathrooms   2 Balconies            NaN
# 482   3 Bathrooms    No Balcony            NaN
# 5    20 Bathrooms  3+ Balconies   Servant Room
# 810   4 Bathrooms  3+ Balconies            NaN
#
#                                                address noOfFloor facing  \
# 319            230/26, Manohar Nagar, Gurgaon, Haryana  4 Floors    NaN
# 592  Mahalaxmi Garden Part-1, Rajendera Park, Secto...  3 Floors  North
# 482     Sector 11, Sector 11 Gurgaon, Gurgaon, Haryana  3 Floors    NaN
# 5                Sushant Lok Phase 1, Gurgaon, Haryana  4 Floors   East
# 810         G-7/6, Sector 26 Gurgaon, Gurgaon, Haryana  4 Floors    NaN
#
#        agePossession                                    nearbyLocations  \
# 319  0 to 1 Year Old  ['Shiv Mahima Patient Care Bureau', 'Navjeevan...
# 592        undefined  ['Palam Vihar Vyapar kendra', 'Chintapurni Man...
# 482        undefined                                                NaN
# 5    1 to 5 Year Old  ['Huda city centre metro station', 'New Life C...
# 810     10+ Year Old  ['Guru dronacharya metro station', 'Sikandarpu...
#
#                                            description  \
# 319  This is a newly constructed building. With pro...
# 592  2 bath, semi-Furnished, ground floor (Of 3), n...
# 482  7bhk residential house for resale in sector 11...
# 5    Best for investment purpose. 3l rupees monthly...
# 810  Sector 26 gurgaon is one of gurgaon's most sou...
#
#                                         furnishDetails  \
# 319  ['36 Fan', '51 Light', 'No AC', 'No Bed', 'No ...
# 592  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 482                                                NaN
# 5    ['1 Water Purifier', '1 Fridge', '20 Fan', '1 ...
# 810                                                 []
#
#                                               features  \
# 319                                                NaN
# 592                                                NaN
# 482                                                NaN
# 5    ['Water Storage', 'Park', 'Visitor Parking', '...
# 810  ['Private Garden / Terrace', 'Maintenance Staf...
#
#                                                 rating property_id
# 319                                                NaN   R69330592
# 592  ['Environment4 out of 5', 'Lifestyle4 out of 5...   J66250436
# 482  ['Environment4 out of 5', 'Lifestyle4 out of 5...   B68022236
# 5    ['Environment5 out of 5', 'Lifestyle5 out of 5...   V69218808
# 810                                                NaN   U70115748

# %%
df.shape
# Out:
# (1037, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1037 non-null   object
#  1   link             1037 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             999 non-null    object
#  5   area             1037 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
#  16  description      1036 non-null   object
#  17  furnishDetails   743 non-null    object
#  18  features         674 non-null    object
#  19  rating           907 non-null    object
#  20  property_id      1036 non-null   object
# dtypes: object(21)
# memory usage: 170.3+ KB

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1024, 21)
