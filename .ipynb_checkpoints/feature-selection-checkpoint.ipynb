# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3554, 18)

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat                 ats triumph  sector 104   4.45
# 1          flat        dlf new town heights   sector 86   1.26
# 2          flat         oriental valley chs   sector 9a   1.50
# 3          flat  ramprastha the edge towers  sector 37d   0.75
# 4          flat          microtek greenburg   sector 86   1.45
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          6846.0        4         5      3+      27.0  Relatively New
# 1          6114.0        3         3       3       5.0  Moderately Old
# 2          9091.0        4         3      3+       8.0  Relatively New
# 3          5319.0        2         2       3      19.0  Moderately Old
# 4          9797.0        3         2       3       8.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# 0         7222.0           0             0           0           0       0
# 1         1747.0           0             1           0           0       1
# 2         1833.0           0             0           0           0       0
# 3         1410.0           0             0           0           0       0
# 4         1480.0           0             0           0           0       0
#
#    furnishing_type  luxury_score
# 0                1           110
# 1                1           113
# 2                0             8
# 3                1            63
# 4                2            72

# %%
train_df = df.drop(columns=['society','price_per_sqft'])

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat  sector 104   4.45        4         5      3+      27.0
# 1          flat   sector 86   1.26        3         3       3       5.0
# 2          flat   sector 9a   1.50        4         3      3+       8.0
# 3          flat  sector 37d   0.75        2         2       3      19.0
# 4          flat   sector 86   1.45        3         2       3       8.0
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Relatively New         7222.0           0             0           0
# 1  Moderately Old         1747.0           0             1           0
# 2  Relatively New         1833.0           0             0           0
# 3  Moderately Old         1410.0           0             0           0
# 4  Relatively New         1480.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           110
# 1           0       1                1           113
# 2           0       0                0             8
# 3           0       0                1            63
# 4           0       0                2            72

# %% [markdown]
# #### luxury score

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
def categorize_luxury(score):
    if 0 <= score < 50:
        return "Low"
    elif 50 <= score < 150:
        return "Medium"
    elif 150 <= score <= 175:
        return "High"
    else:
        return None  # or "Undefined" or any other label for scores outside the defined bins

# %%
train_df['luxury_category'] = train_df['luxury_score'].apply(categorize_luxury)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat  sector 104   4.45        4         5      3+      27.0
# 1          flat   sector 86   1.26        3         3       3       5.0
# 2          flat   sector 9a   1.50        4         3      3+       8.0
# 3          flat  sector 37d   0.75        2         2       3      19.0
# 4          flat   sector 86   1.45        3         2       3       8.0
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Relatively New         7222.0           0             0           0
# 1  Moderately Old         1747.0           0             1           0
# 2  Relatively New         1833.0           0             0           0
# 3  Moderately Old         1410.0           0             0           0
# 4  Relatively New         1480.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score luxury_category
# 0           0       0                1           110          Medium
# 1           0       1                1           113          Medium
# 2           0       0                0             8             Low
# 3           0       0                1            63          Medium
# 4           0       0                2            72          Medium

# %% [markdown]
# #### floorNum

# %%
sns.boxplot(df['floorNum'])
# Out:
# <Axes: ylabel='floorNum'>

# %%
def categorize_floor(floor):
    if 0 <= floor <= 2:
        return "Low Floor"
    elif 3 <= floor <= 10:
        return "Mid Floor"
    elif 11 <= floor <= 51:
        return "High Floor"
    else:
        return None  # or "Undefined" or any other label for floors outside the defined bins

# %%
train_df['floor_category'] = train_df['floorNum'].apply(categorize_floor)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat  sector 104   4.45        4         5      3+      27.0
# 1          flat   sector 86   1.26        3         3       3       5.0
# 2          flat   sector 9a   1.50        4         3      3+       8.0
# 3          flat  sector 37d   0.75        2         2       3      19.0
# 4          flat   sector 86   1.45        3         2       3       8.0
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Relatively New         7222.0           0             0           0
# 1  Moderately Old         1747.0           0             1           0
# 2  Relatively New         1833.0           0             0           0
# 3  Moderately Old         1410.0           0             0           0
# 4  Relatively New         1480.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score luxury_category  \
# 0           0       0                1           110          Medium
# 1           0       1                1           113          Medium
# 2           0       0                0             8             Low
# 3           0       0                1            63          Medium
# 4           0       0                2            72          Medium
#
#   floor_category
# 0     High Floor
# 1      Mid Floor
# 2      Mid Floor
# 3     High Floor
# 4      Mid Floor

# %%
train_df.drop(columns=['floorNum','luxury_score'],inplace=True)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat  sector 104   4.45        4         5      3+  Relatively New
# 1          flat   sector 86   1.26        3         3       3  Moderately Old
# 2          flat   sector 9a   1.50        4         3      3+  Relatively New
# 3          flat  sector 37d   0.75        2         2       3  Moderately Old
# 4          flat   sector 86   1.45        3         2       3  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# 0         7222.0           0             0           0           0       0
# 1         1747.0           0             1           0           0       1
# 2         1833.0           0             0           0           0       0
# 3         1410.0           0             0           0           0       0
# 4         1480.0           0             0           0           0       0
#
#    furnishing_type luxury_category floor_category
# 0                1          Medium     High Floor
# 1                1          Medium      Mid Floor
# 2                0             Low      Mid Floor
# 3                1          Medium     High Floor
# 4                2          Medium      Mid Floor

# %%
final_df = train_df.drop(columns = ['study room' , 'pooja room' , 'others'])

# %%
final_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat  sector 104   4.45        4         5      3+  Relatively New
# 1          flat   sector 86   1.26        3         3       3  Moderately Old
# 2          flat   sector 9a   1.50        4         3      3+  Relatively New
# 3          flat  sector 37d   0.75        2         2       3  Moderately Old
# 4          flat   sector 86   1.45        3         2       3  Relatively New
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0         7222.0             0           0                1          Medium
# 1         1747.0             1           0                1          Medium
# 2         1833.0             0           0                0             Low
# 3         1410.0             0           0                1          Medium
# 4         1480.0             0           0                2          Medium
#
#   floor_category
# 0     High Floor
# 1      Mid Floor
# 2      Mid Floor
# 3     High Floor
# 4      Mid Floor

# %%
final_df.to_csv('gurgaon_properties_post_feature_selection_v2.csv' , index = False)

# %%
from sklearn.preprocessing import OrdinalEncoder

# Create a copy of the original data for label encoding
data_label_encoded = train_df.copy()

categorical_cols = train_df.select_dtypes(include=['object']).columns

# Apply label encoding to categorical columns
for col in categorical_cols:
    oe = OrdinalEncoder()
    data_label_encoded[col] = oe.fit_transform(data_label_encoded[[col]])
    print(oe.categories_)

# Splitting the dataset into training and testing sets
X_label = data_label_encoded.drop('price', axis=1)
y_label = data_label_encoded['price']
# Out:
# [array(['flat', 'house'], dtype=object)]
# [array(['dwarka expressway', 'gwal pahari', 'manesar', 'sector 1',
#        'sector 102', 'sector 103', 'sector 104', 'sector 105',
#        'sector 106', 'sector 107', 'sector 108', 'sector 109',
#        'sector 10a', 'sector 11', 'sector 110', 'sector 111',
#        'sector 112', 'sector 113', 'sector 12', 'sector 13', 'sector 14',
#        'sector 15', 'sector 17', 'sector 17a', 'sector 17b', 'sector 2',
#        'sector 21', 'sector 22', 'sector 23', 'sector 24', 'sector 25',
#        'sector 26', 'sector 27', 'sector 28', 'sector 3',
#        'sector 3 phase 2', 'sector 3 phase 3 extension', 'sector 30',
#        'sector 31', 'sector 33', 'sector 36', 'sector 36a', 'sector 37',
#        'sector 37c', 'sector 37d', 'sector 38', 'sector 39', 'sector 4',
#        'sector 40', 'sector 41', 'sector 43', 'sector 45', 'sector 46',
#        'sector 47', 'sector 48', 'sector 49', 'sector 5', 'sector 50',
#        'sector 51', 'sector 52', 'sector 53', 'sector 54', 'sector 55',
#        'sector 56', 'sector 57', 'sector 58', 'sector 59', 'sector 6',
#        'sector 60', 'sector 61', 'sector 62', 'sector 63', 'sector 63a',
#        'sector 65', 'sector 66', 'sector 67', 'sector 67a', 'sector 68',
#        'sector 69', 'sector 7', 'sector 70', 'sector 70a', 'sector 71',
#        'sector 72', 'sector 73', 'sector 74', 'sector 76', 'sector 77',
#        'sector 78', 'sector 79', 'sector 8', 'sector 80', 'sector 81',
#        'sector 82', 'sector 82a', 'sector 83', 'sector 84', 'sector 85',
#        'sector 86', 'sector 88a', 'sector 88b', 'sector 89', 'sector 9',
#        'sector 90', 'sector 91', 'sector 92', 'sector 93', 'sector 95',
#        'sector 99', 'sector 99a', 'sector 9a', 'sohna road',
#        'sohna road road'], dtype=object)]
# [array(['0', '1', '2', '3', '3+'], dtype=object)]
# [array(['Moderately Old', 'New Property', 'Old Property', 'Relatively New',
#        'Under Construction'], dtype=object)]
# [array(['High', 'Low', 'Medium'], dtype=object)]
# [array(['High Floor', 'Low Floor', 'Mid Floor'], dtype=object)]

# %%
X_label
# Out:
#       property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0               0.0     6.0        4         5      4.0            3.0
# 1               0.0    98.0        3         3      3.0            0.0
# 2               0.0   110.0        4         3      4.0            3.0
# 3               0.0    44.0        2         2      3.0            0.0
# 4               0.0    98.0        3         2      3.0            3.0
# ...             ...     ...      ...       ...      ...            ...
# 3549            0.0     6.0        3         4      4.0            3.0
# 3550            0.0    78.0        3         3      1.0            3.0
# 3551            0.0    39.0        2         2      2.0            3.0
# 3552            1.0     6.0        3         5      4.0            0.0
# 3553            0.0     9.0        3         3      3.0            0.0
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 0            7222.0           0             0           0           0       0
# 1            1747.0           0             1           0           0       1
# 2            1833.0           0             0           0           0       0
# 3            1410.0           0             0           0           0       0
# 4            1480.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3549         2000.0           0             1           0           0       0
# 3550         1392.0           0             0           0           0       0
# 3551          724.0           0             0           0           0       0
# 3552          920.0           0             0           0           0       0
# 3553         1713.0           0             0           0           0       0
#
#       furnishing_type  luxury_category  floor_category
# 0                   1              2.0             0.0
# 1                   1              2.0             2.0
# 2                   0              1.0             2.0
# 3                   1              2.0             0.0
# 4                   2              2.0             2.0
# ...               ...              ...             ...
# 3549                0              2.0             2.0
# 3550                0              0.0             0.0
# 3551                2              1.0             1.0
# 3552                1              1.0             1.0
# 3553                0              2.0             2.0
#
# [3554 rows x 15 columns]

# %%
y_label
# Out:
# 0       4.45
# 1       1.26
# 2       1.50
# 3       0.75
# 4       1.45
#         ...
# 3549    1.05
# 3550    1.40
# 3551    0.40
# 3552    1.95
# 3553    1.21
# Name: price, Length: 3554, dtype: float64

# %% [markdown]
# #### Technique 1 - Correlation Analysis

# %%
sns.heatmap(data_label_encoded.corr())
# Out:
# <Axes: >

# %%
fi_df1 = data_label_encoded.corr()['price'].iloc[1:].to_frame().reset_index().rename(columns={'index':'feature','price':'corr_coeff'})

# %%
fi_df1
# Out:
#             feature  corr_coeff
# 0            sector   -0.201845
# 1             price    1.000000
# 2           bedRoom    0.591289
# 3          bathroom    0.609777
# 4           balcony    0.269637
# 5     agePossession   -0.129866
# 6     built_up_area    0.748574
# 7        study room    0.242955
# 8      servant room    0.391930
# 9        store room    0.305677
# 10       pooja room    0.319852
# 11           others   -0.013064
# 12  furnishing_type   -0.115194
# 13  luxury_category    0.004534
# 14   floor_category    0.042745

# %% [markdown]
# #### Technique 2 - Random Forest Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X_label, y_label)

# Extract feature importance scores for label encoded data
fi_df2 = pd.DataFrame({
    'feature': X_label.columns,
    'rf_importance': rf_label.feature_importances_
}).sort_values(by='rf_importance', ascending=False)

# %%
fi_df2
# Out:
#             feature  rf_importance
# 6     built_up_area       0.646066
# 1            sector       0.104842
# 0     property_type       0.102406
# 2           bedRoom       0.028855
# 3          bathroom       0.024501
# 8      servant room       0.019060
# 5     agePossession       0.014644
# 4           balcony       0.012865
# 12  furnishing_type       0.009810
# 7        study room       0.008599
# 13  luxury_category       0.006796
# 9        store room       0.006690
# 14   floor_category       0.005959
# 10       pooja room       0.005807
# 11           others       0.003100

# %% [markdown]
# #### Technique 3 - Gradient Boosting Feature importances

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Train a Random Forest regressor on label encoded data
gb_label = GradientBoostingRegressor()
gb_label.fit(X_label, y_label)

# Extract feature importance scores for label encoded data
fi_df3 = pd.DataFrame({
    'feature': X_label.columns,
    'gb_importance': gb_label.feature_importances_
}).sort_values(by='gb_importance', ascending=False)

fi_df3
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 # Train a Random Forest regressor on label encoded data
#       4 gb_label = GradientBoostingRegressor()
# ----> 5 gb_label.fit(X_label, y_label)
#       7 # Extract feature importance scores for label encoded data
#       8 fi_df3 = pd.DataFrame({
#       9     'feature': X_label.columns,
#      10     'gb_importance': gb_label.feature_importances_
#      11 }).sort_values(by='gb_importance', ascending=False)
#
# File D:\major project\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File D:\major project\venv\Lib\site-packages\sklearn\ensemble\_gb.py:795, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     792     self._resize_state()
#     794 # fit the boosting stages
# --> 795 n_stages = self._fit_stages(
#     796     X_train,
#     797     y_train,
#     798     raw_predictions,
#     799     sample_weight_train,
#     800     self._rng,
#     801     X_val,
#     802     y_val,
#     803     sample_weight_val,
#     804     begin_at_stage,
#     805     monitor,
#     806 )
#     808 # change shape of arrays after fit (early-stopping or additional ests)
#     809 if n_stages != self.estimators_.shape[0]:
#
# File D:\major project\venv\Lib\site-packages\sklearn\ensemble\_gb.py:891, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     884         initial_loss = factor * self._loss(
#     885             y_true=y_oob_masked,
#     886             raw_prediction=raw_predictions[~sample_mask],
#     887             sample_weight=sample_weight_oob_masked,
#     888         )
#     890 # fit next stage of trees
# --> 891 raw_predictions = self._fit_stage(
#     892     i,
#     893     X,
#     894     y,
#     895     raw_predictions,
#     896     sample_weight,
#     897     sample_mask,
#     898     random_state,
#     899     X_csc=X_csc,
#     900     X_csr=X_csr,
#     901 )
#     903 # track loss
#     904 if do_oob:
#
# File D:\major project\venv\Lib\site-packages\sklearn\ensemble\_gb.py:503, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     501 # update tree leaves
#     502 X_for_tree_update = X_csr if X_csr is not None else X
# --> 503 _update_terminal_regions(
#     504     self._loss,
#     505     tree.tree_,
#     506     X_for_tree_update,
#     507     y,
#     508     neg_g_view[:, k],
#     509     raw_predictions,
#     510     sample_weight,
#     511     sample_mask,
#     512     learning_rate=self.learning_rate,
#     513     k=k,
#     514 )
#     516 # add tree to ensemble
#     517 self.estimators_[i, k] = tree
#
# File D:\major project\venv\Lib\site-packages\sklearn\ensemble\_gb.py:191, in _update_terminal_regions(loss, tree, X, y, neg_gradient, raw_prediction, sample_weight, sample_mask, learning_rate, k)
#     148 """Update the leaf values to be predicted by the tree and raw_prediction.
#     149
#     150 The current raw predictions of the model (of this stage) are updated.
#    (...)    188     The index of the estimator being updated.
#     189 """
#     190 # compute leaf for each sample in ``X``.
# --> 191 terminal_regions = tree.apply(X)
#     193 if not isinstance(loss, HalfSquaredError):
#     194     # mask all which are not in sample mask.
#     195     masked_terminal_regions = terminal_regions.copy()
#
# KeyboardInterrupt:

# %% [markdown]
# #### Technique 4 - Permutation Importance

# %%
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

X_train_label, X_test_label, y_train_label, y_test_label = train_test_split(X_label, y_label, test_size=0.2, random_state=42)

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X_train_label, y_train_label)

# Calculate Permutation Importance
perm_importance = permutation_importance(rf_label, X_test_label, y_test_label, n_repeats=30, random_state=42)

# Organize results into a DataFrame
fi_df4 = pd.DataFrame({
    'feature': X_label.columns,
    'permutation_importance': perm_importance.importances_mean
}).sort_values(by='permutation_importance', ascending=False)

fi_df4

# %% [markdown]
# #### Technique 5 - RFE

# %%
from sklearn.feature_selection import RFE

# Initialize the base estimator
estimator = RandomForestRegressor()

# Apply RFE on the label-encoded and standardized training data
selector_label = RFE(estimator, n_features_to_select=X_label.shape[1], step=1)
selector_label = selector_label.fit(X_label, y_label)

# Get the selected features based on RFE
selected_features = X_label.columns[selector_label.support_]

# Extract the coefficients for the selected features from the underlying linear regression model
selected_coefficients = selector_label.estimator_.feature_importances_

# Organize the results into a DataFrame
fi_df5 = pd.DataFrame({
    'feature': selected_features,
    'rfe_score': selected_coefficients
}).sort_values(by='rfe_score', ascending=False)

# %%
fi_df5

# %%
final_fi_df = fi_df1.merge(fi_df2,on='feature').merge(fi_df3,on='feature').merge(fi_df4,on='feature').merge(fi_df5,on='feature').set_index('feature')

# %%
final_fi_df

# %%
# normalize the score
final_fi_df = final_fi_df.divide(final_fi_df.sum(axis=0), axis=1)

# %%
final_fi_df[['rf_importance','gb_importance','permutation_importance','rfe_score']].mean(axis=1).sort_values(ascending=False)

# %%
# to drop pooja room, study room, others
X_label

# %%
# with all the cols
from sklearn.model_selection import cross_val_score

rf = RandomForestRegressor(n_estimators=100, random_state=42)

scores = cross_val_score(rf, X_label, y_label, cv=5, scoring='r2')

# %%
scores.mean()

# %%
export_df = X_label.drop(columns=['pooja room', 'study room', 'others'])
export_df['price'] = y_label

# %%
export_df.to_csv('gurgaon_properties_post_feature_selection.csv', index=False)

# %%
export_df
